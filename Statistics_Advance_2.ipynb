# %% [markdown]
# ###THEORY

# %% [markdown]
# 1- What is hypothesis testing in statistics?

# %% [markdown]
# - Hypothesis testing is a statistical method used to make decisions or inferences about population parameters based on sample data. It involves stating a hypothesis, collecting data, and determining whether the data support or contradict the hypothesis.

# %% [markdown]
# 2- What is the null hypothesis, and how does it differ from the alternative hypothesis?

# %% [markdown]
# - Null Hypothesis (H₀): The default assumption that there is no effect or no difference.
#
# Alternative Hypothesis (H₁ or Ha): The statement that contradicts the null; it represents what you want to prove.
#
# Example:
#
# H₀: Mean = 50
#
# H₁: Mean ≠ 50

# %% [markdown]
# 3- What is the significance level in hypothesis testing, and why is it important?

# %% [markdown]
# - The significance level (α) is the probability of rejecting the null hypothesis when it is actually true (Type I error).
#
# Common values: 0.05 (5%), 0.01 (1%)
#
# It's important because it sets the threshold for deciding if results are statistically significant.

# %% [markdown]
# 4- What does a P-value represent in hypothesis testing?

# %% [markdown]
# - The P-value is the probability of obtaining test results at least as extreme as the observed results, assuming the null hypothesis is true.

# %% [markdown]
# 5- How do you interpret the P-value in hypothesis testing?

# %% [markdown]
# - If P-value ≤ α → Reject H₀ (evidence supports H₁)
#
# If P-value > α → Fail to reject H₀ (not enough evidence)
#
# Example:
# If α = 0.05 and P-value = 0.03 → Reject H₀

# %% [markdown]
# 6- What are Type 1 and Type 2 errors in hypothesis testing?

# %% [markdown]
# - Type I Error (α): Rejecting H₀ when it's true
#
# Type II Error (β): Failing to reject H₀ when it's false
#
# Error Type	Meaning	Consequence
# Type I	False positive	Unnecessary action
# Type II	False negative	Missed opportunity

# %% [markdown]
# 7- What is the difference between a one-tailed and a two-tailed test in hypothesis testing?

# %% [markdown]
# - One-tailed test: Tests for deviation in one direction (e.g., greater than or less than)
#
# Two-tailed test: Tests for deviation in both directions (e.g., not equal to)

# %% [markdown]
# 8- What is the Z-test, and when is it used in hypothesis testing?

# %% [markdown]
# - The Z-test is used to test hypotheses about population means when:
#
# The sample size is large (n > 30)
#
# Population standard deviation is known

# %% [markdown]
# 9- How do you calculate the Z-score, and what does it represent in hypothesis testing?

# %% [markdown]
# - Z-score formula:
#
# 𝑍
# =
# 𝑥
# ˉ
# −
# 𝜇
# 𝜎
# /
# 𝑛
# Z=
# σ/
# n
# ​
#
# x
# ˉ
#  −μ
# ​
#
# Where:
#
# 𝑥
# ˉ
# x
# ˉ
#  : Sample mean
#
# 𝜇
# μ: Population mean
#
# 𝜎
# σ: Population standard deviation
#
# 𝑛
# n: Sample size
#
# Interpretation: How many standard deviations the sample mean is from the population mean.

# %% [markdown]
# 10- What is the T-distribution, and when should it be used instead of the normal distribution?

# %% [markdown]
# - The T-distribution is used when:
#
# The sample size is small (n ≤ 30)
#
# The population standard deviation is unknown
#
# It accounts for extra variability in small samples.

# %% [markdown]
# 11- What is the difference between a Z-test and a T-test?

# %% [markdown]
# - Z-test	T-test
# Large samples (n > 30)	Small samples (n ≤ 30)
# Population σ is known	Population σ is unknown
# Uses Z-distribution	Uses T-distribution

# %% [markdown]
# 12- What is the T-test, and how is it used in hypothesis testing?

# %% [markdown]
# - A T-test is used to compare means:
#
# One-sample T-test: Mean of one group vs population
#
# Two-sample T-test: Means of two independent groups
#
# Paired T-test: Means of same group before and after

# %% [markdown]
# 13- What is the relationship between Z-test and T-test in hypothesis testing?

# %% [markdown]
# - Both are used to compare sample means
#
# Both follow the same logic (test statistic vs critical value)
#
# T-test becomes Z-test as sample size increases (T-distribution approximates normal)

# %% [markdown]
# 14- What is a confidence interval, and how is it used to interpret statistical results?

# %% [markdown]
# -A confidence interval (CI) gives a range of values within which the true population parameter is likely to fall, with a given confidence level (e.g., 95%).
#
# Interpretation:
# “We are 95% confident that the true mean lies between X and Y.”

# %% [markdown]
# 15- What is the margin of error, and how does it affect the confidence interval?

# %% [markdown]
# - Margin of Error (MOE) is the amount added/subtracted from the sample estimate to create the confidence interval.
#
# Wider MOE → wider CI → less precise
#
# Narrower MOE → more precise estimate

# %% [markdown]
# 16- How is Bayes' Theorem used in statistics, and what is its significance?

# %% [markdown]
# - Bayes' Theorem updates the probability of a hypothesis based on new evidence.
#
# Formula:
#
# 𝑃
# (
# 𝐴
# ∣
# 𝐵
# )
# =
# 𝑃
# (
# 𝐵
# ∣
# 𝐴
# )
# ⋅
# 𝑃
# (
# 𝐴
# )
# 𝑃
# (
# 𝐵
# )
# P(A∣B)=
# P(B)
# P(B∣A)⋅P(A)
# ​
#
# Significance: Used in predictive modeling, spam filtering, diagnostics, etc.

# %% [markdown]
# 17- What is the Chi-square distribution, and when is it used?

# %% [markdown]
# - The Chi-square (χ²) distribution is used for categorical data and tests of variance or goodness-of-fit. It is positively skewed and only takes non-negative values.

# %% [markdown]
# 18- What is the Chi-square goodness of fit test, and how is it applied?

# %% [markdown]
# - This test checks if the observed frequencies match expected frequencies for categorical variables.
#
# Formula:
#
# 𝜒
# 2
# =
# ∑
# (
# 𝑂
# −
# 𝐸
# )
# 2
# 𝐸
# χ
# 2
#  =∑
# E
# (O−E)
# 2
#
# ​
#
# Where O = Observed, E = Expected

# %% [markdown]
# 19- What is the F-distribution, and when is it used in hypothesis testing?

# %% [markdown]
# - The F-distribution is used to compare two variances or in ANOVA. It is right-skewed and depends on two degrees of freedom.

# %% [markdown]
# 20- What is an ANOVA test, and what are its assumptions?

# %% [markdown]
# - ANOVA (Analysis of Variance) tests if three or more group means are significantly different.
#
# Assumptions:
#
# Independence of observations
#
# Normal distribution
#
# Equal variances (homogeneity of variance)

# %% [markdown]
# 21- What are the different types of ANOVA tests?

# %% [markdown]
# - One-way ANOVA: One independent variable
#
# Two-way ANOVA: Two independent variables
#
# Repeated Measures ANOVA: Same subjects measured repeatedly

# %% [markdown]
# 22- What is the F-test, and how does it relate to hypothesis testing?

# %% [markdown]
# - An F-test compares variances between groups.
# In ANOVA, the F-test checks if the variability between group means is larger than expected by chance.

# %% [markdown]
# ###Practical Part - 1

# %% [markdown]
# 1- Write a Python program to generate a random variable and display its value.

# %%
import numpy as np

# Generate a random number between 0 and 1
random_var = np.random.rand()
print("Random variable value:", random_var)
# Out:
# Random variable value: 0.08209685381894372

# %% [markdown]
# 2- Generate a discrete uniform distribution using Python and plot the probability mass function (PMF).

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import randint

# Discrete uniform distribution from 1 to 6 (like a die)
x = np.arange(1, 7)
pmf = randint.pmf(x, 1, 7)

plt.stem(x, pmf, basefmt=" ")
plt.title("PMF of Discrete Uniform Distribution (1 to 6)")
plt.xlabel("Outcome")
plt.ylabel("Probability")
plt.grid(True)
plt.show()

# %% [markdown]
# 3- Write a Python function to calculate the probability distribution function (PDF) of a Bernoulli distribution.

# %%
from scipy.stats import bernoulli

def bernoulli_pdf(p):
    x = [0, 1]
    pdf = bernoulli.pmf(x, p)
    return dict(zip(x, pdf))

# Example: Bernoulli distribution with p = 0.7
result = bernoulli_pdf(0.7)
print("Bernoulli PDF:", result)
# Out:
# Bernoulli PDF: {0: np.float64(0.30000000000000004), 1: np.float64(0.7)}

# %% [markdown]
# 4- Write a Python script to simulate a binomial distribution with n=10 and p=0.5, then plot its histogram.

# %%
import numpy as np
import matplotlib.pyplot as plt

n = 10
p = 0.5
size = 1000

data = np.random.binomial(n, p, size)

plt.hist(data, bins=np.arange(-0.5, n+1.5), edgecolor='black', density=True)
plt.title("Binomial Distribution Histogram (n=10, p=0.5)")
plt.xlabel("Number of Successes")
plt.ylabel("Frequency")
plt.grid(True)
plt.show()

# %% [markdown]
# 5- Create a Poisson distribution and visualize it using Python.

# %%
from scipy.stats import poisson
import matplotlib.pyplot as plt
import numpy as np

mu = 4
x = np.arange(0, 15)
pmf = poisson.pmf(x, mu)

plt.stem(x, pmf, basefmt=" ")
plt.title("Poisson Distribution (mu=4)")
plt.xlabel("Number of Events")
plt.ylabel("Probability")
plt.grid(True)
plt.show()

# %% [markdown]
# 6- Write a Python program to calculate and plot the cumulative distribution function (CDF) of a discrete uniform distribution.

# %%
from scipy.stats import randint
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(1, 8)
cdf = randint.cdf(x, 1, 7)

plt.step(x, cdf, where='post')
plt.title("CDF of Discrete Uniform Distribution (1 to 6)")
plt.xlabel("Value")
plt.ylabel("Cumulative Probability")
plt.grid(True)
plt.show()

# %% [markdown]
# 7- Generate a continuous uniform distribution using NumPy and visualize it.

# %%
import numpy as np
import matplotlib.pyplot as plt

data = np.random.uniform(low=0.0, high=10.0, size=1000)

plt.hist(data, bins=30, edgecolor='black', density=True)
plt.title("Histogram of Continuous Uniform Distribution [0, 10]")
plt.xlabel("Value")
plt.ylabel("Density")
plt.grid(True)
plt.show()

# %% [markdown]
# 8- Simulate data from a normal distribution and plot its histogram.

# %%
import numpy as np
import matplotlib.pyplot as plt

mu = 0
sigma = 1
data = np.random.normal(mu, sigma, 1000)

plt.hist(data, bins=30, edgecolor='black', density=True)
plt.title("Normal Distribution Histogram (mean=0, std=1)")
plt.xlabel("Value")
plt.ylabel("Density")
plt.grid(True)
plt.show()

# %% [markdown]
# 9- Write a Python function to calculate Z-scores from a dataset and plot them.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import zscore

def calculate_z_scores(data):
    return zscore(data)

# Generate data
data = np.random.normal(50, 10, 100)
z_scores = calculate_z_scores(data)

plt.hist(z_scores, bins=30, edgecolor='black', density=True)
plt.title("Histogram of Z-scores")
plt.xlabel("Z-score")
plt.ylabel("Density")
plt.grid(True)
plt.show()

# %% [markdown]
# 10- Implement the Central Limit Theorem (CLT) using Python for a non-normal distribution

# %%
import numpy as np
import matplotlib.pyplot as plt

# Population: exponential distribution (non-normal)
population = np.random.exponential(scale=2.0, size=100000)

sample_means = []
sample_size = 30

for _ in range(1000):
    sample = np.random.choice(population, size=sample_size)
    sample_means.append(np.mean(sample))

# Plot sample means
plt.hist(sample_means, bins=30, edgecolor='black', density=True)
plt.title("Central Limit Theorem in Action (Exponential Population)")
plt.xlabel("Sample Mean")
plt.ylabel("Density")
plt.grid(True)
plt.show()

# %% [markdown]
# 11- Simulate multiple samples from a normal distribution and verify the Central Limit Theorem

# %%
import numpy as np
import matplotlib.pyplot as plt

population = np.random.normal(loc=50, scale=20, size=100000)

sample_means = []
for _ in range(1000):
    sample = np.random.choice(population, size=30)
    sample_means.append(np.mean(sample))

plt.hist(sample_means, bins=30, edgecolor='black', density=True)
plt.title("Verification of Central Limit Theorem")
plt.xlabel("Sample Mean")
plt.ylabel("Density")
plt.grid(True)
plt.show()

# %% [markdown]
# 12- Write a Python function to calculate and plot the standard normal distribution (mean = 0, std = 1)

# %%
from scipy.stats import norm
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-4, 4, 1000)
pdf = norm.pdf(x, loc=0, scale=1)

plt.plot(x, pdf, label="Standard Normal Distribution")
plt.title("Standard Normal Distribution PDF")
plt.xlabel("Z")
plt.ylabel("Probability Density")
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# 13- Generate random variables and calculate their corresponding probabilities using the binomial distribution

# %%
from scipy.stats import binom
import numpy as np

n = 10
p = 0.5
x = np.arange(0, n+1)
pmf = binom.pmf(x, n, p)

print("Binomial probabilities (n=10, p=0.5):")
for i, prob in zip(x, pmf):
    print(f"P(X={i}) = {prob:.4f}")
# Out:
# Binomial probabilities (n=10, p=0.5):
# P(X=0) = 0.0010
# P(X=1) = 0.0098
# P(X=2) = 0.0439
# P(X=3) = 0.1172
# P(X=4) = 0.2051
# P(X=5) = 0.2461
# P(X=6) = 0.2051
# P(X=7) = 0.1172
# P(X=8) = 0.0439
# P(X=9) = 0.0098
# P(X=10) = 0.0010

# %% [markdown]
# 14- Write a Python program to calculate the Z-score for a given data point and compare it to a standard normal distribution

# %%
from scipy.stats import norm

def compute_z_score(x, mean, std_dev):
    return (x - mean) / std_dev

x_value = 75
mean = 60
std_dev = 10
z = compute_z_score(x_value, mean, std_dev)

p = norm.cdf(z)

print(f"Z-score: {z:.2f}")
print(f"Probability that X <= {x_value}: {p:.4f}")
# Out:
# Z-score: 1.50
# Probability that X <= 75: 0.9332

# %% [markdown]
# 15- Implement hypothesis testing using Z-statistics for a sample dataset

# %%
import numpy as np
from scipy.stats import norm

# Sample
data = np.array([50, 52, 48, 51, 49, 53, 47])
sample_mean = np.mean(data)
population_mean = 50
std_dev = 2
n = len(data)

z = (sample_mean - population_mean) / (std_dev / np.sqrt(n))
p_value = 2 * (1 - norm.cdf(abs(z)))

print(f"Z-statistic: {z:.2f}")
print(f"P-value: {p_value:.4f}")
# Out:
# Z-statistic: 0.00
# P-value: 1.0000

# %% [markdown]
# 16- Create a confidence interval for a dataset using Python and interpret the result

# %%
import numpy as np
from scipy.stats import norm

data = np.random.normal(100, 15, 50)
mean = np.mean(data)
std_err = np.std(data, ddof=1) / np.sqrt(len(data))
z = norm.ppf(0.975)

ci_lower = mean - z * std_err
ci_upper = mean + z * std_err

print(f"95% Confidence Interval: [{ci_lower:.2f}, {ci_upper:.2f}]")
# Out:
# 95% Confidence Interval: [96.04, 104.20]

# %% [markdown]
# 17- Generate data from a normal distribution, then calculate and interpret the confidence interval for its mean

# %%
import numpy as np
from scipy.stats import norm

data = np.random.normal(loc=70, scale=10, size=100)
mean = np.mean(data)
se = np.std(data, ddof=1) / np.sqrt(len(data))
z = norm.ppf(0.975)

ci = (mean - z*se, mean + z*se)
print(f"Sample mean: {mean:.2f}")
print(f"95% CI for mean: {ci[0]:.2f} to {ci[1]:.2f}")
# Out:
# Sample mean: 70.08
# 95% CI for mean: 68.41 to 71.76

# %% [markdown]
# 18- Write a Python script to calculate and visualize the probability density function (PDF) of a normal distribution

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

x = np.linspace(40, 100, 1000)
mu, sigma = 70, 10
pdf = norm.pdf(x, mu, sigma)

plt.plot(x, pdf)
plt.title("PDF of Normal Distribution (μ=70, σ=10)")
plt.xlabel("x")
plt.ylabel("Density")
plt.grid(True)
plt.show()

# %% [markdown]
# 19- Use Python to calculate and interpret the cumulative distribution function (CDF) of a Poisson distribution

# %%
from scipy.stats import poisson

mu = 3
x = 4
cdf_value = poisson.cdf(x, mu)
print(f"P(X ≤ {x}) with Poisson(μ=3): {cdf_value:.4f}")
# Out:
# P(X ≤ 4) with Poisson(μ=3): 0.8153

# %% [markdown]
# 20- Simulate a random variable using a continuous uniform distribution and calculate its expected value

# %%
import numpy as np

low, high = 10, 20
samples = np.random.uniform(low, high, size=10000)
expected_value = np.mean(samples)
print(f"Expected value (mean): {expected_value:.2f}")
# Out:
# Expected value (mean): 14.96

# %% [markdown]
# 21- Write a Python program to compare the standard deviations of two datasets and visualize the difference

# %%
import numpy as np
import matplotlib.pyplot as plt

data1 = np.random.normal(50, 5, 1000)
data2 = np.random.normal(50, 15, 1000)

std1 = np.std(data1)
std2 = np.std(data2)

print(f"Standard Deviation of Dataset 1: {std1:.2f}")
print(f"Standard Deviation of Dataset 2: {std2:.2f}")

plt.hist(data1, bins=30, alpha=0.6, label="SD=5")
plt.hist(data2, bins=30, alpha=0.6, label="SD=15")
plt.legend()
plt.title("Comparison of Standard Deviations")
plt.show()
# Out:
# Standard Deviation of Dataset 1: 5.05
# Standard Deviation of Dataset 2: 14.70

# %% [markdown]
# 22- Calculate the range and interquartile range (IQR) of a dataset generated from a normal distribution

# %%
import numpy as np

data = np.random.normal(100, 20, 1000)
data_range = np.max(data) - np.min(data)
q75, q25 = np.percentile(data, [75 ,25])
iqr = q75 - q25

print(f"Range: {data_range:.2f}")
print(f"IQR: {iqr:.2f}")
# Out:
# Range: 131.43
# IQR: 25.47

# %% [markdown]
# 23- Implement Z-score normalization on a dataset and visualize its transformation

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import zscore

data = np.random.normal(100, 15, 1000)
z_data = zscore(data)

plt.hist(z_data, bins=30, edgecolor='black')
plt.title("Z-score Normalized Data")
plt.xlabel("Z-score")
plt.ylabel("Frequency")
plt.grid(True)
plt.show()

# %% [markdown]
# 24- Write a Python function to calculate the skewness and kurtosis of a dataset generated from a normal distribution

# %%
from scipy.stats import skew, kurtosis
import numpy as np

data = np.random.normal(0, 1, 1000)

def get_skew_kurtosis(dataset):
    return skew(dataset), kurtosis(dataset)

skew_val, kurt_val = get_skew_kurtosis(data)
print(f"Skewness: {skew_val:.4f}")
print(f"Kurtosis: {kurt_val:.4f}")
# Out:
# Skewness: -0.0754
# Kurtosis: -0.1432

# %% [markdown]
# ###Practical Part - 2

# %% [markdown]
# 1- Write a Python program to perform a Z-test for comparing a sample mean to a known population mean and interpret the results

# %%
from scipy.stats import norm
import numpy as np

sample = [72, 74, 71, 69, 70, 75, 73]
sample_mean = np.mean(sample)
population_mean = 70
population_std = 3
n = len(sample)

z = (sample_mean - population_mean) / (population_std / np.sqrt(n))
p_value = 2 * (1 - norm.cdf(abs(z)))

print(f"Z = {z:.2f}, P-value = {p_value:.4f}")
# Out:
# Z = 1.76, P-value = 0.0778

# %% [markdown]
# 2- Simulate random data to perform hypothesis testing and calculate the corresponding P-value using Python

# %%
import numpy as np
from scipy.stats import norm

data = np.random.normal(loc=52, scale=5, size=30)
mu = 50
std = 5
z = (np.mean(data) - mu) / (std / np.sqrt(len(data)))
p = 2 * (1 - norm.cdf(abs(z)))

print(f"Sample Mean: {np.mean(data):.2f}")
print(f"Z-statistic: {z:.2f}, P-value: {p:.4f}")
# Out:
# Sample Mean: 52.18
# Z-statistic: 2.39, P-value: 0.0169

# %% [markdown]
# 3- Implement a one-sample Z-test using Python to compare the sample mean with the population mean

# %%
def one_sample_z_test(sample, population_mean, population_std):
    import numpy as np
    from scipy.stats import norm

    n = len(sample)
    sample_mean = np.mean(sample)
    z = (sample_mean - population_mean) / (population_std / np.sqrt(n))
    p = 2 * (1 - norm.cdf(abs(z)))
    return z, p

sample = [58, 60, 62, 63, 61, 64, 65]
z, p = one_sample_z_test(sample, 60, 3)
print(f"Z-score: {z:.2f}, P-value: {p:.4f}")
# Out:
# Z-score: 1.64, P-value: 0.1015

# %% [markdown]
# 4- Perform a two-tailed Z-test using Python and visualize the decision region on a plot

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

z_stat = 2.1
alpha = 0.05
z_critical = norm.ppf(1 - alpha/2)

x = np.linspace(-4, 4, 1000)
y = norm.pdf(x)

plt.plot(x, y)
plt.fill_between(x, y, where=(x <= -z_critical) | (x >= z_critical), color='red', alpha=0.3, label='Rejection Region')
plt.axvline(z_stat, color='blue', linestyle='--', label=f"Z-stat = {z_stat}")
plt.title("Two-tailed Z-test Visualization")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# 5- Create a Python function that calculates and visualizes Type 1 and Type 2 errors during hypothesis testing.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

mu0 = 50  # Null hypothesis
mu1 = 53  # Alternative hypothesis
sigma = 5
alpha = 0.05
n = 30

se = sigma / np.sqrt(n)
z_alpha = norm.ppf(1 - alpha)
x = np.linspace(40, 60, 1000)

# Distributions
h0_pdf = norm.pdf(x, mu0, se)
h1_pdf = norm.pdf(x, mu1, se)

plt.plot(x, h0_pdf, label='H0 Distribution')
plt.plot(x, h1_pdf, label='H1 Distribution')
plt.axvline(mu0 + z_alpha * se, color='red', linestyle='--', label='Critical Value')
plt.fill_between(x, h0_pdf, where=x >= mu0 + z_alpha * se, color='red', alpha=0.3, label='Type I Error')
plt.fill_between(x, h1_pdf, where=x < mu0 + z_alpha * se, color='orange', alpha=0.3, label='Type II Error')
plt.title("Type I and Type II Errors")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# 6- Write a Python program to perform an independent T-test and interpret the results.

# %%
from scipy.stats import ttest_ind
import numpy as np

group1 = np.random.normal(70, 10, 30)
group2 = np.random.normal(75, 12, 30)

t_stat, p = ttest_ind(group1, group2)

print(f"T-statistic: {t_stat:.2f}, P-value: {p:.4f}")
# Out:
# T-statistic: -3.27, P-value: 0.0018

# %% [markdown]
# 7- Perform a paired sample T-test using Python and visualize the comparison results

# %%
from scipy.stats import ttest_rel
import numpy as np
import matplotlib.pyplot as plt

before = np.random.normal(80, 5, 20)
after = before + np.random.normal(-2, 3, 20)

t_stat, p = ttest_rel(before, after)

plt.plot(before, label='Before')
plt.plot(after, label='After')
plt.title("Paired T-test Visualization")
plt.legend()
plt.grid(True)
plt.show()

print(f"Paired T-test: T = {t_stat:.2f}, P = {p:.4f}")
# Out:
# Paired T-test: T = 5.24, P = 0.0000

# %% [markdown]
# 8- Simulate data and perform both Z-test and T-test, then compare the results using Python

# %%
from scipy.stats import ttest_1samp, norm
import numpy as np

data = np.random.normal(52, 10, 30)
pop_mean = 50
pop_std = 10

# Z-test
z = (np.mean(data) - pop_mean) / (pop_std / np.sqrt(len(data)))
p_z = 2 * (1 - norm.cdf(abs(z)))

# T-test
t_stat, p_t = ttest_1samp(data, pop_mean)

print(f"Z-test: Z = {z:.2f}, P = {p_z:.4f}")
print(f"T-test: T = {t_stat:.2f}, P = {p_t:.4f}")
# Out:
# Z-test: Z = 1.35, P = 0.1772
# T-test: T = 1.35, P = 0.1885

# %% [markdown]
# 9- Write a Python function to calculate the confidence interval for a sample mean and explain its significance

# %%
from scipy.stats import norm
import numpy as np

def confidence_interval(data, confidence=0.95):
    mean = np.mean(data)
    se = np.std(data, ddof=1) / np.sqrt(len(data))
    z = norm.ppf((1 + confidence) / 2)
    return (mean - z*se, mean + z*se)

sample = np.random.normal(100, 10, 50)
ci = confidence_interval(sample)
print(f"95% Confidence Interval: {ci[0]:.2f} to {ci[1]:.2f}")
# Out:
# 95% Confidence Interval: 96.77 to 102.58

# %% [markdown]
# 10- Write a Python program to calculate the margin of error for a given confidence level using sample data.

# %%
from scipy.stats import norm
import numpy as np

data = np.random.normal(100, 15, 40)
std_err = np.std(data, ddof=1) / np.sqrt(len(data))
z = norm.ppf(0.975)  # 95% confidence
margin = z * std_err

print(f"Margin of Error: {margin:.2f}")
# Out:
# Margin of Error: 3.78

# %% [markdown]
# 11- Implement a Bayesian inference method using Bayes' Theorem in Python and explain the process

# %%
def bayes_theorem(p_a, p_b_given_a, p_b_given_not_a):
    p_not_a = 1 - p_a
    p_b = p_b_given_a * p_a + p_b_given_not_a * p_not_a
    p_a_given_b = (p_b_given_a * p_a) / p_b
    return p_a_given_b

# Example: Disease testing
p_disease = 0.01
p_pos_given_disease = 0.99
p_pos_given_no_disease = 0.05

posterior = bayes_theorem(p_disease, p_pos_given_disease, p_pos_given_no_disease)
print(f"Probability of disease given positive test: {posterior:.4f}")
# Out:
# Probability of disease given positive test: 0.1667

# %% [markdown]
# 12- Perform a Chi-square test for independence between two categorical variables in Python

# %%
import pandas as pd
from scipy.stats import chi2_contingency

data = pd.DataFrame([[30, 10], [20, 40]], columns=["Yes", "No"], index=["Group1", "Group2"])
chi2, p, dof, expected = chi2_contingency(data)

print("Chi-square Test for Independence")
print(f"Chi2 = {chi2:.2f}, p-value = {p:.4f}")
# Out:
# Chi-square Test for Independence
# Chi2 = 15.04, p-value = 0.0001

# %% [markdown]
# 13- Write a Python program to calculate the expected frequencies for a Chi-square test based on observed data

# %%
import numpy as np
import pandas as pd
from scipy.stats import chi2_contingency

observed = np.array([[20, 30], [30, 20]])
chi2, p, dof, expected = chi2_contingency(observed)

print("Observed Frequencies:\n", observed)
print("Expected Frequencies:\n", np.round(expected, 2))
# Out:
# Observed Frequencies:
#  [[20 30]
#  [30 20]]
# Expected Frequencies:
#  [[25. 25.]
#  [25. 25.]]

# %% [markdown]
# 14- Perform a goodness-of-fit test using Python to compare the observed data to an expected distribution.

# %%
from scipy.stats import chisquare

observed = [18, 22, 20, 25, 15]
expected = [20, 20, 20, 20, 20]

chi2, p = chisquare(observed, f_exp=expected)

print(f"Chi-square = {chi2:.2f}, P-value = {p:.4f}")
# Out:
# Chi-square = 2.90, P-value = 0.5747
